# %%
#@ImageJ ij
# Out:
# No Outputs

# %%
myImg = ij.io().open("https://c532f75abb9c1c021b8c-e46e473f8aadb72cf2a8ea564b4e6a76.ssl.cf5.rackcdn.com/2016/08/31/27ti5gwrzr_Julie_Larsen_Maher_3242_African_Elephant_UGA_06_30_10_hr.jpg")
# Out:
# [INFO] Populating metadata

# %%
import net.imglib2.interpolation.randomaccess.NLinearInterpolatorFactory

scaleFactors = [0.4, 0.4, 1] // Reduce X and Y to 40%; leave C dimension alone.
interpolationStrategy = new NLinearInterpolatorFactory()

myImgScaled = ij.op().run("scaleView", myImg, scaleFactors, interpolationStrategy)
